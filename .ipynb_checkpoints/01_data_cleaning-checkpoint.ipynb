# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('GlobalWeatherRepository.csv')
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (144432, 41)
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  2024-05-16 13:15                 26.6
# 1          1715849100  2024-05-16 10:45                 19.0
# 2          1715849100  2024-05-16 09:45                 23.0
# 3          1715849100  2024-05-16 10:45                  6.3
# 4          1715849100  2024-05-16 09:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# ...

# %%
# Step 2: Basic info about the dataset
print("=== Dataset Info ===")
print(f"Rows: {df.shape[0]}")
print(f"Columns: {df.shape[1]}")
print("\n=== Column Names ===")
print(df.columns.tolist())
print("\n=== Data Types ===")
print(df.dtypes)
print("\n=== Missing Values ===")
print(df.isnull().sum())
# Out:
# === Dataset Info ===
# Rows: 144432
# Columns: 41
#
# === Column Names ===
# ['country', 'location_name', 'latitude', 'longitude', 'timezone', 'last_updated_epoch', 'last_updated', 'temperature_celsius', 'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph', 'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in', 'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius', 'feels_like_fahrenheit', 'visibility_km', 'visibility_miles', 'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide', 'air_quality_Ozone', 'air_quality_Nitrogen_dioxide', 'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10', 'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise', 'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination']
#
# === Data Types ===
# country                          object
# location_name                    object
# latitude                        float64
# longitude                       float64
# ...

# %%
# Step 3: Check duplicates and fix data types
print("=== Duplicate Rows ===")
print(f"Number of duplicates: {df.duplicated().sum()}")

# Convert last_updated to datetime (important for time series later!)
df['last_updated'] = pd.to_datetime(df['last_updated'])

# Extract useful time features
df['year'] = df['last_updated'].dt.year
df['month'] = df['last_updated'].dt.month
df['day'] = df['last_updated'].dt.day
df['hour'] = df['last_updated'].dt.hour

print("\n=== Date Range ===")
print(f"From: {df['last_updated'].min()}")
print(f"To:   {df['last_updated'].max()}")

print("\n=== Sample Countries ===")
print(df['country'].nunique(), "unique countries")
print(df['country'].unique()[:20])
# Out:
# === Duplicate Rows ===
# Number of duplicates: 0
#
# === Date Range ===
# From: 2024-05-16 01:45:00
# To:   2026-05-30 19:15:00
#
# === Sample Countries ===
# 211 unique countries
# ['Afghanistan' 'Albania' 'Algeria' 'Andorra' 'Angola'
#  'Antigua and Barbuda' 'Argentina' 'Armenia' 'Australia' 'Austria'
#  'Azerbaijan' 'Bahamas' 'Bahrain' 'Bangladesh' 'Barbados' 'Belarus'
#  'Belgium' 'Belize' 'Benin' 'Bhutan']

# %%
# Step 4: Statistical summary and outlier detection
print("=== Statistical Summary ===")
df.describe().round(2)
# Out:
# === Statistical Summary ===
#         latitude  longitude  last_updated_epoch  \
# count  144432.00  144432.00        1.444320e+05
# mean       19.22      21.93        1.747993e+09
# min       -41.30    -175.20        1.715849e+09
# 25%         4.05      -6.84        1.732006e+09
# 50%        17.25      23.24        1.747991e+09
# 75%        40.40      49.88        1.763968e+09
# max        64.15     179.22        1.780122e+09
# std        24.41      65.78        1.855475e+07
#
#                         last_updated  temperature_celsius  \
# count                         144432            144432.00
# mean   2025-05-23 11:49:39.187438080                21.26
# min              2024-05-16 01:45:00               -29.80
# 25%              2024-11-19 05:00:00                15.70
# 50%              2025-05-23 12:00:00                23.70
# 75%              2025-11-24 13:52:30                27.90
# max              2026-05-30 19:15:00                79.30
# ...

# %%
# Step 5: Remove outliers using IQR method
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return df[(df[column] >= lower) & (df[column] <= upper)]

# Apply to key columns
original_size = len(df)
df = remove_outliers_iqr(df, 'temperature_celsius')
df = remove_outliers_iqr(df, 'wind_mph')
df = remove_outliers_iqr(df, 'humidity')
df = remove_outliers_iqr(df, 'pressure_mb')

print(f"Rows before: {original_size}")
print(f"Rows after:  {len(df)}")
print(f"Removed:     {original_size - len(df)} outliers")
# Out:
# Rows before: 144432
# Rows after:  136315
# Removed:     8117 outliers

# %%
# Step 6: Normalize numerical columns and save clean data
from sklearn.preprocessing import MinMaxScaler

# Select numerical columns to normalize
num_cols = ['temperature_celsius', 'humidity', 'wind_mph', 
            'pressure_mb', 'precip_mm', 'visibility_km', 'uv_index']

# Create normalized versions (keep originals too)
scaler = MinMaxScaler()
df_scaled = df.copy()
df_scaled[num_cols] = scaler.fit_transform(df[num_cols])

# Save the clean dataset
df.to_csv('cleaned_weather_data.csv', index=False)
print("✅ Clean dataset saved as 'cleaned_weather_data.csv'")
print(f"Final shape: {df.shape}")
print("\nNormalized sample:")
df_scaled[num_cols].head(3).round(3)
# Out:
# ✅ Clean dataset saved as 'cleaned_weather_data.csv'
# Final shape: (136315, 45)
#
# Normalized sample:
#    temperature_celsius  humidity  wind_mph  pressure_mb  precip_mm  \
# 0                0.599     0.224     0.313        0.438      0.000
# 1                0.442     0.939     0.241        0.438      0.002
# 2                0.525     0.276     0.369        0.406      0.000
#
#    visibility_km  uv_index
# 0          0.312     0.429
# 1          0.312     0.307
# 2          0.312     0.307
