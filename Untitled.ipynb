# %%
# Phase 1 — Step 1: Import libraries and load dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('GlobalWeatherRepository.csv')

# First look at the data
print("Shape:", df.shape)
print("\nFirst 5 rows:")
df.head()
